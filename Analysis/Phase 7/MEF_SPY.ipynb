# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\A-CMSI research\Data\features.csv")

# %%
losses = -df["spy_ret"].dropna()

# %%
thresholds = np.quantile(
    losses,
    np.linspace(0.80, 0.99, 60)
)

# %%
mean_excess = []
for u in thresholds:

    exceedances = losses[losses > u] - u

    if len(exceedances) > 0:
        mean_excess.append(exceedances.mean())
    else:
        mean_excess.append(np.nan)

# %%
plt.figure(figsize=(10,6))

plt.plot(
    thresholds,
    mean_excess,
    marker='o',
    linewidth=2,
    markersize=5
)

plt.xlabel("Threshold (u)")
plt.ylabel("Mean Excess")
plt.title("Mean Excess Function (MEF) - SPY")

plt.grid(True)

plt.show()

# %%
mef_table = pd.DataFrame({
    "Threshold": thresholds,
    "MeanExcess": mean_excess
})

# %%
mef_table
# Out:
#     Threshold  MeanExcess
# 0    0.005459    0.008759
# 1    0.005557    0.008805
# 2    0.005612    0.008898
# 3    0.005804    0.008857
# 4    0.006020    0.008776
# 5    0.006145    0.008805
# 6    0.006279    0.008828
# 7    0.006424    0.008845
# 8    0.006586    0.008846
# 9    0.006660    0.008940
# 10   0.006741    0.009031
# 11   0.006830    0.009120
# 12   0.006914    0.009219
# 13   0.007251    0.009068
# 14   0.007341    0.009146
# 15   0.007557    0.009124
# 16   0.007658    0.009221
# 17   0.007780    0.009305
# 18   0.007876    0.009420
# 19   0.008116    0.009399
# 20   0.008289    0.009450
# 21   0.008434    0.009536
# 22   0.008665    0.009542
# 23   0.008825    0.009626
# 24   0.009008    0.009668
# 25   0.009194    0.009742
# 26   0.009393    0.009812
# 27   0.009911    0.009569
# 28   0.010222    0.009538
# 29   0.010456    0.009591
# 30   0.010796    0.009546
# 31   0.011013    0.009635
# 32   0.011287    0.009680
# 33   0.011546    0.009753
# 34   0.011907    0.009697
# 35   0.012226    0.009735
# 36   0.012556    0.009776
# 37   0.012855    0.009864
# 38   0.013307    0.009819
# 39   0.013573    0.009974
# 40   0.013916    0.010079
# 41   0.014222    0.010248
# 42   0.014548    0.010428
# 43   0.015090    0.010423
# 44   0.015505    0.010511
# 45   0.016071    0.010545
# 46   0.016631    0.010628
# 47   0.017033    0.010921
# 48   0.017759    0.010950
# 49   0.018095    0.011446
# 50   0.018713    0.011756
# 51   0.019816    0.011660
# 52   0.020710    0.011886
# 53   0.021544    0.012171
# 54   0.022880    0.012273
# 55   0.024210    0.012557
# 56   0.025440    0.013273
# 57   0.027772    0.013322
# 58   0.030247    0.013715
# 59   0.032688    0.015450

# %%
##
import numpy as np 
thresholds_1 = np.quantile(
    losses,
    np.linspace(0.85, 0.999, 60)
)

# %%
mean_excess_1 = []

for u in thresholds_1:

    exceedances = losses[losses > u] - u

    if len(exceedances) > 0:
        mean_excess_1.append(exceedances.mean())
    else:
        mean_excess_1.append(np.nan)

# %%
plt.figure(figsize=(10,6))

plt.plot(
    thresholds_1,
    mean_excess_1,
    marker='o',
    linewidth=2,
    markersize=5
)

plt.xlabel("Threshold_1 (u)")
plt.ylabel("Mean Excess_1")
plt.title("Mean Excess Function_1 (MEF) - SPY")

plt.grid(True)

plt.show()

# %%
mef_table_1 = pd.DataFrame({
    "Threshold": thresholds_1,
    "MeanExcess": mean_excess_1
})

mef_table_1
# Out:
#     Threshold  MeanExcess
# 0    0.007621    0.009169
# 1    0.007675    0.009272
# 2    0.007805    0.009303
# 3    0.007874    0.009399
# 4    0.008060    0.009382
# 5    0.008168    0.009446
# 6    0.008295    0.009495
# 7    0.008434    0.009536
# 8    0.008608    0.009546
# 9    0.008748    0.009594
# 10   0.008868    0.009668
# 11   0.009070    0.009664
# 12   0.009189    0.009747
# 13   0.009364    0.009781
# 14   0.009619    0.009740
# 15   0.010039    0.009533
# 16   0.010268    0.009524
# 17   0.010428    0.009586
# 18   0.010706    0.009537
# 19   0.010933    0.009544
# 20   0.011041    0.009677
# 21   0.011287    0.009680
# 22   0.011491    0.009733
# 23   0.011765    0.009724
# 24   0.012003    0.009757
# 25   0.012281    0.009720
# 26   0.012529    0.009760
# 27   0.012710    0.009877
# 28   0.012959    0.009938
# 29   0.013419    0.009798
# 30   0.013580    0.009967
# 31   0.013873    0.010020
# 32   0.014098    0.010157
# 33   0.014359    0.010276
# 34   0.014630    0.010405
# 35   0.015084    0.010368
# 36   0.015379    0.010507
# 37   0.015879    0.010466
# 38   0.016297    0.010530
# 39   0.016668    0.010664
# 40   0.016987    0.010886
# 41   0.017568    0.010884
# 42   0.017887    0.011179
# 43   0.018173    0.011566
# 44   0.018745    0.011724
# 45   0.019731    0.011514
# 46   0.020306    0.011776
# 47   0.021073    0.011927
# 48   0.021645    0.012374
# 49   0.022725    0.012428
# 50   0.024079    0.012304
# 51   0.024970    0.012838
# 52   0.025949    0.013513
# 53   0.027996    0.013393
# 54   0.030092    0.013509
# 55   0.030791    0.015770
# 56   0.033998    0.016574
# 57   0.038365    0.018156
# 58   0.045105    0.021090
# 59   0.065300    0.033956

# %%
##
import numpy as np 
thresholds_2 = np.quantile(
    losses,
    np.linspace(0.90, 0.999, 60)
)

# %%
mean_excess_2 = []

for u in thresholds_2:

    exceedances = losses[losses > u] - u

    if len(exceedances) > 0:
        mean_excess_2.append(exceedances.mean())
    else:
        mean_excess_2.append(np.nan)

# %%
plt.figure(figsize=(10,6))

plt.plot(
    thresholds_2,
    mean_excess_2,
    marker='o',
    linewidth=2,
    markersize=5
)

plt.xlabel("Threshold_2 (u)")
plt.ylabel("Mean Excess_2")
plt.title("Mean Excess Function_2 (MEF) - SPY")

plt.grid(True)

plt.show()

# %%
mef_table_2 = pd.DataFrame({
    "Threshold": thresholds_2,
    "MeanExcess": mean_excess_2
})

mef_table_2
# Out:
#     Threshold  MeanExcess
# 0    0.011028    0.009620
# 1    0.011143    0.009681
# 2    0.011291    0.009676
# 3    0.011478    0.009671
# 4    0.011568    0.009768
# 5    0.011829    0.009660
# 6    0.011946    0.009736
# 7    0.012056    0.009824
# 8    0.012283    0.009758
# 9    0.012475    0.009773
# 10   0.012628    0.009830
# 11   0.012711    0.009920
# 12   0.012912    0.009940
# 13   0.013093    0.009942
# 14   0.013446    0.009818
# 15   0.013561    0.009938
# 16   0.013697    0.009998
# 17   0.013887    0.010057
# 18   0.014061    0.010141
# 19   0.014205    0.010211
# 20   0.014406    0.010285
# 21   0.014547    0.010428
# 22   0.014789    0.010423
# 23   0.015137    0.010376
# 24   0.015355    0.010404
# 25   0.015555    0.010525
# 26   0.015927    0.010485
# 27   0.016090    0.010596
# 28   0.016465    0.010575
# 29   0.016679    0.010729
# 30   0.016915    0.010800
# 31   0.017173    0.010944
# 32   0.017602    0.010935
# 33   0.017838    0.011047
# 34   0.017932    0.011415
# 35   0.018186    0.011553
# 36   0.018647    0.011608
# 37   0.019271    0.011526
# 38   0.019779    0.011465
# 39   0.020179    0.011657
# 40   0.020653    0.011813
# 41   0.021090    0.011910
# 42   0.021506    0.012209
# 43   0.022026    0.012468
# 44   0.022811    0.012342
# 45   0.023869    0.012152
# 46   0.024224    0.012543
# 47   0.025062    0.012746
# 48   0.025544    0.013415
# 49   0.026823    0.013162
# 50   0.028062    0.013327
# 51   0.029610    0.013310
# 52   0.030292    0.014051
# 53   0.030797    0.015765
# 54   0.033660    0.015620
# 55   0.034946    0.017078
# 56   0.038387    0.018134
# 57   0.044014    0.017160
# 58   0.048409    0.022834
# 59   0.065300    0.033956

# %%
##
import numpy as np 
thresholds_3 = np.quantile(
    losses,
    np.linspace(0.95, 0.999, 60)
)

# %%
mean_excess_3 = []

for u in thresholds_3:

    exceedances = losses[losses > u] - u

    if len(exceedances) > 0:
        mean_excess_3.append(exceedances.mean())
    else:
        mean_excess_3.append(np.nan)

# %%
plt.figure(figsize=(10,6))

plt.plot(
    thresholds_3,
    mean_excess_3 ,
    marker='o',
    linewidth=2,
    markersize=5
)

plt.xlabel("Threshold_3 (u)")
plt.ylabel("Mean Excess_3")
plt.title("Mean Excess Function_3 (MEF) - SPY")

plt.grid(True)

plt.show()

# %%
mef_table_3 = pd.DataFrame({
    "Threshold": thresholds_3,
    "MeanExcess": mean_excess_3
})

mef_table_3
# Out:
#     Threshold  MeanExcess
# 0    0.016888    0.010749
# 1    0.016976    0.010897
# 2    0.017103    0.010932
# 3    0.017228    0.010972
# 4    0.017518    0.010934
# 5    0.017697    0.010925
# 6    0.017805    0.010992
# 7    0.017866    0.011108
# 8    0.017905    0.011347
# 9    0.018024    0.011419
# 10   0.018148    0.011491
# 11   0.018234    0.011709
# 12   0.018628    0.011521
# 13   0.018671    0.011690
# 14   0.018860    0.011717
# 15   0.019401    0.011506
# 16   0.019616    0.011515
# 17   0.019811    0.011548
# 18   0.019949    0.011766
# 19   0.020242    0.011716
# 20   0.020354    0.011854
# 21   0.020706    0.011890
# 22   0.020892    0.011972
# 23   0.021107    0.012031
# 24   0.021453    0.011971
# 25   0.021555    0.012310
# 26   0.021762    0.012413
# 27   0.022222    0.012271
# 28   0.022540    0.012443
# 29   0.022975    0.012348
# 30   0.023496    0.012171
# 31   0.024034    0.011987
# 32   0.024108    0.012465
# 33   0.024260    0.012706
# 34   0.024698    0.012681
# 35   0.025266    0.012758
# 36   0.025417    0.013059
# 37   0.025744    0.013215
# 38   0.026060    0.013666
# 39   0.026887    0.013366
# 40   0.027593    0.013215
# 41   0.028259    0.013130
# 42   0.029397    0.012883
# 43   0.029747    0.013172
# 44   0.030197    0.013404
# 45   0.030328    0.014416
# 46   0.030647    0.014958
# 47   0.030815    0.015747
# 48   0.032539    0.015061
# 49   0.033677    0.015603
# 50   0.034174    0.016398
# 51   0.034991    0.017033
# 52   0.036759    0.017806
# 53   0.038454    0.018067
# 54   0.042350    0.016384
# 55   0.044074    0.018527
# 56   0.045212    0.020983
# 57   0.048593    0.022650
# 58   0.051877    0.026361
# 59   0.065300    0.033956

# %%
##
import numpy as np 
thresholds_4 = np.quantile(
    losses,
    np.linspace(0.97, 0.999, 60)
)

# %%
mean_excess_4 = []

for u in thresholds_4:

    exceedances = losses[losses > u] - u

    if len(exceedances) > 0:
        mean_excess_4.append(exceedances.mean())
    else:
        mean_excess_4.append(np.nan)

# %%
plt.figure(figsize=(10,6))

plt.plot(
    thresholds_4,
    mean_excess_4 ,
    marker='o',
    linewidth=2,
    markersize=5
)

plt.xlabel("Threshold_4 (u)")
plt.ylabel("Mean Excess_4")
plt.title("Mean Excess Function_4 (MEF) - SPY")

plt.grid(True)

plt.show()

# %%
mef_table_4 = pd.DataFrame({
    "Threshold": thresholds_4,
    "MeanExcess": mean_excess_4
})

mef_table_4
# Out:
#     Threshold  MeanExcess
# 0    0.021475    0.012093
# 1    0.021509    0.012206
# 2    0.021585    0.012281
# 3    0.021722    0.012453
# 4    0.021924    0.012409
# 5    0.022247    0.012247
# 6    0.022494    0.012322
# 7    0.022549    0.012434
# 8    0.022914    0.012238
# 9    0.023189    0.012306
# 10   0.023496    0.012171
# 11   0.023798    0.012223
# 12   0.024051    0.012148
# 13   0.024086    0.012297
# 14   0.024161    0.012605
# 15   0.024254    0.012711
# 16   0.024374    0.012796
# 17   0.024748    0.012842
# 18   0.025039    0.012769
# 19   0.025310    0.012714
# 20   0.025417    0.013059
# 21   0.025439    0.013275
# 22   0.025835    0.013124
# 23   0.025943    0.013519
# 24   0.026555    0.013171
# 25   0.026840    0.013413
# 26   0.027166    0.013363
# 27   0.027636    0.013173
# 28   0.027886    0.013502
# 29   0.028666    0.013020
# 30   0.029339    0.012642
# 31   0.029452    0.013142
# 32   0.029764    0.013155
# 33   0.030007    0.013246
# 34   0.030244    0.013719
# 35   0.030286    0.014057
# 36   0.030534    0.014628
# 37   0.030637    0.014967
# 38   0.030770    0.015298
# 39   0.030934    0.016152
# 40   0.032334    0.015266
# 41   0.032856    0.015282
# 42   0.033667    0.015613
# 43   0.033768    0.016134
# 44   0.034351    0.016221
# 45   0.034831    0.017192
# 46   0.035701    0.017132
# 47   0.036547    0.017119
# 48   0.037827    0.017678
# 49   0.038544    0.017977
# 50   0.041169    0.017564
# 51   0.042833    0.017044
# 52   0.043772    0.017402
# 53   0.044487    0.019763
# 54   0.045319    0.020876
# 55   0.046030    0.022414
# 56   0.050068    0.024213
# 57   0.051278    0.026961
# 58   0.058479    0.025015
# 59   0.065300    0.033956
