# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\A-CMSI research\Data\features.csv")

# %%
losses = -df["msft_ret"].dropna()

# %%
thresholds = np.quantile(
    losses,
    np.linspace(0.80, 0.99, 60)
)

# %%
mean_excess = []
for u in thresholds:

    exceedances = losses[losses > u] - u

    if len(exceedances) > 0:
        mean_excess.append(exceedances.mean())
    else:
        mean_excess.append(np.nan)

# %%
plt.figure(figsize=(10,6))

plt.plot(
    thresholds,
    mean_excess,
    marker='o',
    linewidth=2,
    markersize=5
)

plt.xlabel("Threshold (u)")
plt.ylabel("Mean Excess")
plt.title("Mean Excess Function (MEF) - MSFT")

plt.grid(True)

plt.show()

# %%
mef_table = pd.DataFrame({
    "Threshold": thresholds,
    "MeanExcess": mean_excess
})

# %%
mef_table
# Out:
#     Threshold  MeanExcess
# 0    0.009267    0.012244
# 1    0.009606    0.012104
# 2    0.009716    0.012197
# 3    0.009911    0.012210
# 4    0.010067    0.012240
# 5    0.010207    0.012315
# 6    0.010404    0.012338
# 7    0.010624    0.012342
# 8    0.010852    0.012343
# 9    0.011045    0.012383
# 10   0.011325    0.012340
# 11   0.011655    0.012250
# 12   0.011839    0.012312
# 13   0.012086    0.012315
# 14   0.012340    0.012288
# 15   0.012581    0.012307
# 16   0.012844    0.012311
# 17   0.013053    0.012376
# 18   0.013244    0.012466
# 19   0.013355    0.012646
# 20   0.013590    0.012712
# 21   0.013910    0.012701
# 22   0.014134    0.012794
# 23   0.014444    0.012812
# 24   0.014752    0.012801
# 25   0.014981    0.012917
# 26   0.015334    0.012922
# 27   0.015770    0.012853
# 28   0.016122    0.012876
# 29   0.016560    0.012823
# 30   0.016983    0.012798
# 31   0.017512    0.012674
# 32   0.018030    0.012573
# 33   0.018379    0.012654
# ...

# %%
##
import numpy as np 
thresholds_1 = np.quantile(
    losses,
    np.linspace(0.85, 0.999, 60)
)

# %%
mean_excess_1 = []

for u in thresholds_1:

    exceedances = losses[losses > u] - u

    if len(exceedances) > 0:
        mean_excess_1.append(exceedances.mean())
    else:
        mean_excess_1.append(np.nan)

# %%
plt.figure(figsize=(10,6))

plt.plot(
    thresholds_1,
    mean_excess_1,
    marker='o',
    linewidth=2,
    markersize=5
)

plt.xlabel("Threshold_1 (u)")
plt.ylabel("Mean Excess_1")
plt.title("Mean Excess Function_1 (MEF) - MSFT")

plt.grid(True)

plt.show()

# %%
mef_table_1 = pd.DataFrame({
    "Threshold": thresholds_1,
    "MeanExcess": mean_excess_1
})

mef_table_1
# Out:
#     Threshold  MeanExcess
# 0    0.012757    0.012279
# 1    0.012891    0.012354
# 2    0.013063    0.012396
# 3    0.013228    0.012451
# 4    0.013314    0.012589
# 5    0.013413    0.012721
# 6    0.013638    0.012733
# 7    0.013915    0.012697
# 8    0.014061    0.012797
# 9    0.014285    0.012825
# 10   0.014544    0.012822
# 11   0.014802    0.012827
# 12   0.014940    0.012958
# 13   0.015220    0.012955
# 14   0.015475    0.012983
# 15   0.015823    0.012924
# 16   0.016155    0.012887
# 17   0.016520    0.012820
# 18   0.016816    0.012831
# 19   0.017218    0.012742
# 20   0.017568    0.012710
# 21   0.018029    0.012574
# 22   0.018333    0.012603
# 23   0.018605    0.012675
# 24   0.018947    0.012686
# 25   0.019321    0.012624
# 26   0.019681    0.012637
# 27   0.020000    0.012705
# 28   0.020315    0.012791
# 29   0.020624    0.012897
# 30   0.020935    0.013020
# 31   0.021441    0.012967
# 32   0.021679    0.013197
# 33   0.022194    0.013172
# ...

# %%
##
import numpy as np 
thresholds_2 = np.quantile(
    losses,
    np.linspace(0.90, 0.999, 60)
)

# %%
mean_excess_2 = []

for u in thresholds_2:

    exceedances = losses[losses > u] - u

    if len(exceedances) > 0:
        mean_excess_2.append(exceedances.mean())
    else:
        mean_excess_2.append(np.nan)

# %%
plt.figure(figsize=(10,6))

plt.plot(
    thresholds_2,
    mean_excess_2,
    marker='o',
    linewidth=2,
    markersize=5
)

plt.xlabel("Threshold_2 (u)")
plt.ylabel("Mean Excess_2")
plt.title("Mean Excess Function_2 (MEF) - MSFT")

plt.grid(True)

plt.show()

# %%
mef_table_2 = pd.DataFrame({
    "Threshold": thresholds_2,
    "MeanExcess": mean_excess_2
})

mef_table_2
# Out:
#     Threshold  MeanExcess
# 0    0.017535    0.012651
# 1    0.017776    0.012640
# 2    0.018049    0.012554
# 3    0.018283    0.012557
# 4    0.018436    0.012646
# 5    0.018628    0.012651
# 6    0.018877    0.012655
# 7    0.019072    0.012717
# 8    0.019343    0.012655
# 9    0.019596    0.012668
# 10   0.019778    0.012760
# 11   0.020015    0.012746
# 12   0.020182    0.012865
# 13   0.020458    0.012824
# 14   0.020655    0.012927
# 15   0.020890    0.013002
# 16   0.021088    0.013058
# 17   0.021474    0.012998
# 18   0.021639    0.013169
# 19   0.021821    0.013264
# 20   0.022368    0.013071
# 21   0.022839    0.012954
# 22   0.023314    0.012771
# 23   0.023672    0.012783
# 24   0.023988    0.012771
# 25   0.024505    0.012643
# 26   0.024669    0.012880
# 27   0.024932    0.012954
# 28   0.025388    0.012931
# 29   0.026233    0.012524
# 30   0.026602    0.012515
# 31   0.026963    0.012617
# 32   0.027317    0.012749
# 33   0.027483    0.012993
# ...

# %%
##
import numpy as np 
thresholds_3 = np.quantile(
    losses,
    np.linspace(0.95, 0.999, 60)
)

# %%
mean_excess_3 = []

for u in thresholds_3:

    exceedances = losses[losses > u] - u

    if len(exceedances) > 0:
        mean_excess_3.append(exceedances.mean())
    else:
        mean_excess_3.append(np.nan)

# %%
plt.figure(figsize=(10,6))

plt.plot(
    thresholds_3,
    mean_excess_3 ,
    marker='o',
    linewidth=2,
    markersize=5
)

plt.xlabel("Threshold_3 (u)")
plt.ylabel("Mean Excess_3")
plt.title("Mean Excess Function_3 (MEF) - MSFT")

plt.grid(True)

plt.show()

# %%
mef_table_3 = pd.DataFrame({
    "Threshold": thresholds_3,
    "MeanExcess": mean_excess_3
})

mef_table_3
# Out:
#     Threshold  MeanExcess
# 0    0.026466    0.012560
# 1    0.026671    0.012629
# 2    0.026943    0.012543
# 3    0.027013    0.012663
# 4    0.027178    0.012790
# 5    0.027344    0.012823
# 6    0.027423    0.012949
# 7    0.027717    0.012865
# 8    0.028202    0.012694
# 9    0.028283    0.012828
# 10   0.028481    0.012849
# 11   0.028676    0.012992
# 12   0.028811    0.013090
# 13   0.029393    0.012744
# 14   0.029501    0.012873
# 15   0.029532    0.013213
# 16   0.029599    0.013404
# 17   0.029784    0.013485
# 18   0.029966    0.013719
# 19   0.030072    0.013900
# 20   0.030477    0.013793
# 21   0.030653    0.014073
# 22   0.031430    0.013598
# 23   0.031751    0.013589
# 24   0.032120    0.013540
# 25   0.032370    0.013786
# 26   0.032545    0.013959
# 27   0.032838    0.014024
# 28   0.033230    0.014191
# 29   0.033866    0.013939
# 30   0.034300    0.013898
# 31   0.034477    0.014127
# 32   0.035160    0.014081
# 33   0.036019    0.013652
# ...

# %%
##
import numpy as np 
thresholds_4 = np.quantile(
    losses,
    np.linspace(0.97, 0.999, 60)
)

# %%
mean_excess_4 = []

for u in thresholds_4:

    exceedances = losses[losses > u] - u

    if len(exceedances) > 0:
        mean_excess_4.append(exceedances.mean())
    else:
        mean_excess_4.append(np.nan)

# %%
plt.figure(figsize=(10,6))

plt.plot(
    thresholds_4,
    mean_excess_4 ,
    marker='o',
    linewidth=2,
    markersize=5
)

plt.xlabel("Threshold_4 (u)")
plt.ylabel("Mean Excess_4")
plt.title("Mean Excess Function_4 (MEF) - MSFT")

plt.grid(True)

plt.show()

# %%
mef_table_4 = pd.DataFrame({
    "Threshold": thresholds_4,
    "MeanExcess": mean_excess_4
})

mef_table_4
# Out:
#     Threshold  MeanExcess
# 0    0.032139    0.013684
# 1    0.032312    0.013676
# 2    0.032378    0.013778
# 3    0.032477    0.014027
# 4    0.032733    0.013950
# 5    0.032842    0.014021
# 6    0.033148    0.014084
# 7    0.033375    0.014047
# 8    0.033766    0.013847
# 9    0.034052    0.013948
# 10   0.034300    0.013898
# 11   0.034382    0.014222
# 12   0.034633    0.014181
# 13   0.035017    0.014009
# 14   0.035477    0.013980
# 15   0.036017    0.013654
# 16   0.036133    0.013757
# 17   0.036273    0.014075
# 18   0.036714    0.013868
# 19   0.037256    0.013562
# 20   0.037344    0.013957
# 21   0.037491    0.014062
# 22   0.037643    0.014170
# 23   0.038161    0.014188
# 24   0.038269    0.014357
# 25   0.038290    0.014921
# 26   0.038409    0.015111
# 27   0.038500    0.015340
# 28   0.039087    0.015423
# 29   0.039247    0.015612
# 30   0.039675    0.015544
# 31   0.039926    0.016045
# 32   0.040518    0.015848
# 33   0.040837    0.015929
# ...
